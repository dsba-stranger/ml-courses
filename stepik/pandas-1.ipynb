# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_min = df.iloc[:5, [-1, -2, -3]]

# %%
df_min.index = ['Max', 'Alex', 'Bob', 'Jack', 'Michael']

# %%
df_min.head()
# Out:
#          writing score  reading score  math score
# Max                 74             72          72
# Alex                88             90          69
# Bob                 93             95          90
# Jack                44             57          47
# Michael             75             78          76

# %%
df_min.loc[['Max', 'Jack'], ['reading score']]
# Out:
#       reading score
# Max              72
# Jack             57

# %%
df_min.select_dtypes(exclude=['object'])
# Out:
#          writing score  reading score  math score
# Max                 74             72          72
# Alex                88             90          69
# Bob                 93             95          90
# Jack                44             57          47
# Michael             75             78          76

# %%
df_min[['writing score', 'math score']]
# Out:
#          writing score  math score
# Max                 74          72
# Alex                88          69
# Bob                 93          90
# Jack                44          47
# Michael             75          76

# %%
df.loc[df.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
len(df[df['lunch'] == 'free/reduced']) / len(df)
# Out:
# 0.355

# %%
df[df['lunch'] == 'standard'].mean().mean()
# Out:
# 70.83720930232558

# %%
df[df['lunch'] == 'free/reduced'].mean().mean()
# Out:
# 62.19906103286385

# %%
df[df['lunch'] == 'standard'].std().mean()
# Out:
# 13.941196762151867

# %%
df[df['lunch'] == 'free/reduced'].std().mean()
# Out:
# 15.16303941469122

# %%
df.query('gender == "female" and lunch == "standard"')
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# ..      ...            ...                         ...       ...
# 984  female        group C            some high school  standard
# 986  female        group C          associate's degree  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
df = df.rename(columns={'parental level of education': 'parental_level_of_education', 'math score': 'math_score', 'reading score': 'reading_score', 'writing score': 'writing_score'})

# %%
df.filter(like='score')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
df.filter(regex='[5]', axis=0)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 5    female        group B          associate's degree      standard
# 15   female        group C            some high school      standard
# 25     male        group A             master's degree  free/reduced
# 35     male        group E          associate's degree      standard
# 45     male        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 959    male        group C                 high school      standard
# 965  female        group D                some college      standard
# 975  female        group C                some college      standard
# 985    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.groupby(['gender', 'race/ethnicity']).aggregate({'math_score': 'mean'})
# Out:
#                        math_score
# gender race/ethnicity
# female group A          58.527778
#        group B          61.403846
#        group C          62.033333
#        group D          65.248062
#        group E          70.811594
# male   group A          63.735849
#        group B          65.930233
#        group C          67.611511
#        group D          69.413534
#        group E          76.746479

# %%
df['total_score'] = df.filter(like='score').aggregate('sum', axis=1)

# %%
df
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading_score  writing_score  \
# ...

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')

# %%
my_stat.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9

# %%
my_stat.query('n_users < 0')['n_users'] = my_stat.query('n_users > 0')['n_users'].mean()

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B      9.0
# 1            NaN    11     A      0.7
# 2            1.0     8     A      1.0
# 3            2.0     9     B      3.0
# 4            2.0    10     B      9.0
# 5            3.0     8     A      8.0
# 6            NaN    11     B      5.0
# 7            0.0     9     A      4.0
# 8            0.0     8     B      0.7
# 9            0.0     9     A      0.7

# %%
my_stat.groupby('group', as_index=False).agg({'session_value': 'mean'}).rename(columns={'session_value': 'mean_session_value'})
# Out:
#   group  mean_session_value
# 0     A                 1.0
# 1     B                 1.0
